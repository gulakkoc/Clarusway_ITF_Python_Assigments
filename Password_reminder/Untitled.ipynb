# %%
name = 'Joseph'

your_name = input (" Please enter your name :  ")
if your_name == name:
    print ('Hello, Joseph! The password is : W@12')
else :
    print ("Hello", your_name,"!", "See you later!")
